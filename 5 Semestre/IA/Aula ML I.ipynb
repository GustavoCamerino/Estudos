# %%
# !pip install seaborn
# !pip install scikit-learn
# !pip install pandas

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine

# %% [markdown]
# ### Wine Data Set
# Using chemical analysis determine the origin of wines
#
# https://archive.ics.uci.edu/ml/datasets/wine

# %% [markdown]
# Baixa e carrega dados

# %%
data = load_wine()

# %% [markdown]
# Separa variáveis e labels

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.DataFrame(data.target)

# %% [markdown]
# Plota váriaveis com identificação de cada label

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,8)})

sns.scatterplot(data=X, x='alcohol', y='hue', hue=y.values.reshape(-1), s=100)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='hue'>

# %%
sns.pairplot(pd.concat([X, y], axis=1), hue=0)

# %%
X
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
y_mini = y.head(130)
X_mini = X.head(130)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(10,8)})

sns.scatterplot(data=X_mini, x='alcohol', y='hue', hue=y_mini.values.reshape(-1), s=100)
# Out:
# <Axes: xlabel='alcohol', ylabel='hue'>
